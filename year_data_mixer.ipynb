# %%
import pandas as pd

# %%
years = [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
base_df = pd.read_csv('Resources/year_subregions/2006.csv')
base_df
# Out:
#                   Region Counter Strike: (2006)  Fortnite: (2006)  \
# 0                 Nevada                   100%               NaN
# 1             California                   100%               NaN
# 2              Wisconsin                   100%               NaN
# 3                 Oregon                   100%               NaN
# 4             Washington                   100%               NaN
# 5                   Utah                   100%               NaN
# 6                   Ohio                   100%               NaN
# 7                Florida                   100%               NaN
# 8                  Maine                   100%               NaN
# 9               Kentucky                    98%               NaN
# 10            New Jersey                   100%               NaN
# 11           Connecticut                   100%               NaN
# 12                Kansas                   100%               NaN
# ...

# %%
for year in years:
    next_df = pd.read_csv(f'Resources/year_subregions/{year}.csv')
    base_df = base_df.join(next_df.set_index('Region'), on = 'Region')

# %%
base_df = base_df.fillna('0%')

# %%
base_df = base_df.replace({'<':''}, regex=True)
base_df = base_df.replace({'%':''}, regex=True)
base_df.columns = base_df.columns.str.replace(' ', '')

# %%
base_df
# Out:
#                   Region CounterStrike:(2006) Fortnite:(2006) Dota2:(2006)  \
# 0                 Nevada                  100               0            0
# 1             California                  100               0            1
# 2              Wisconsin                  100               0            0
# 3                 Oregon                  100               0            0
# 4             Washington                  100               0            0
# 5                   Utah                  100               0            0
# 6                   Ohio                  100               0            0
# 7                Florida                  100               0            0
# 8                  Maine                  100               0            0
# 9               Kentucky                   98               0            0
# 10            New Jersey                  100               0            1
# ...

# %%
base_df.to_csv('Resources/Year_Subregions_Clean.csv', index=False)
